# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("mobile_price.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# # a. Partition the data set, for example 75% of the records are included in the training data set and 25% are included in the test data set. Use a bar graph to confirm your proportions.

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.2)

# %%
train
#  75% of the records are included in the training data set
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 121             772     1          2.4         1   1       1          10
# 1393           1444     1          2.1         1   0       0           6
# 741            1972     0          1.2         1   0       0          37
# 1690           1606     1          0.5         1   0       1          33
# 1216           1158     0          0.7         1   1       1          29
# ...             ...   ...          ...       ...  ..     ...         ...
# 506            1260     1          2.0         1   2       1          23
# 201            1445     1          2.4         1   7       1          20
# 542             569     0          0.6         1   2       0          39
# 683            1713     0          2.5         1   1       0          27
# 25              961     1          1.4         1   0       1          57
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
test
# 25% are included in the test data set
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 175             946     0          1.7         1   8       1          25
# 646             543     1          0.5         1   4       1          60
# 208             664     1          1.1         1   1       1          51
# 1637           1695     1          0.5         1   2       1          47
# 1272           1174     0          0.7         1   1       1          25
# ...             ...   ...          ...       ...  ..     ...         ...
# 151             742     0          2.2         1   4       0          56
# 305            1348     0          2.0         0  18       0          52
# 390            1836     1          1.7         1   3       0          26
# 1979           1614     0          1.2         0   1       1           9
# 590             612     1          0.7         0   6       0          35
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
plt.bar(df.battery_power,df.px_height)
# Out:
# <BarContainer object of 2000 artists>

# %%
plt.bar(test.battery_power,test.px_height)
# Out:
# <BarContainer object of 400 artists>

# %% [markdown]
# # b. Identify the total number of records in the training data set.

# %%
rows = len(df.axes[0])
cols = len(df.axes[1]) 
print(df)
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# # c. Validate your partition by performing a two‐sample Z‐test.

# %%
from statsmodels.stats.weightstats import ztest as ztest

# %%
ztest(train, test, value=0)
# Out:
# (array([-0.21476826,  0.33526864,  0.97963495,  0.76012997, -0.81371291,
#          0.73831688,  0.4330599 , -0.73644483, -0.41270661, -1.14361351,
#         -1.1745024 ,  0.38275691,  0.3362414 , -0.36627288,  1.38816361,
#          0.58761361,  1.43681411,  1.78448676, -1.09547389,  0.98371237,
#         -0.39981594]),
#  array([0.829948  , 0.73742245, 0.32726635, 0.4471769 , 0.41580944,
#         0.46032191, 0.66497125, 0.46146003, 0.67982158, 0.25278396,
#         0.24019385, 0.70190001, 0.73668883, 0.71416147, 0.16508723,
#         0.55679167, 0.15077082, 0.0743446 , 0.27330908, 0.32525696,
#         0.68929209]))
