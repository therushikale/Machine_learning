# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("mobile_price.csv")

# %%
df.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
df.index.name="n_cores"
df
# Out:
#          battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# n_cores
# 1745               926     1          0.8         0   6       1          59
# 1330              1766     1          1.3         0   1       0          29
# 1982              1784     0          1.6         0   4       0          41
# 1354              1998     1          1.2         0   8       0          31
# 1761              1329     1          1.7         0   5       1          23
# ...                ...   ...          ...       ...  ..     ...         ...
# 555               1230     1          2.2         1   6       0          26
# 723               1271     0          0.5         1   2       0          54
# 683               1713     0          2.5         1   1       0          27
# 578               1195     0          2.0         1   1       1          23
# 940               1456     0          1.6         1   9       1          39
#
# ...

# %%
df.isnull()
# Out:
#       battery_power   blue  clock_speed  dual_sim     fc  four_g  int_memory  \
# 1745          False  False        False     False  False   False       False
# 1330          False  False        False     False  False   False       False
# 1982          False  False        False     False  False   False       False
# 1354          False  False        False     False  False   False       False
# 1761          False  False        False     False  False   False       False
# ...             ...    ...          ...       ...    ...     ...         ...
# 555           False  False        False     False  False   False       False
# 723           False  False        False     False  False   False       False
# 683           False  False        False     False  False   False       False
# 578           False  False        False     False  False   False       False
# 940           False  False        False     False  False   False       False
#
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
null_series = pd.isnull(df["battery_power"]) 
null_series
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: battery_power, Length: 2000, dtype: bool

# %%
from scipy import stats
 
z = np.abs(stats.zscore(df['int_memory']))
print(z)
# Out:
# 0       1.380644
# 1       1.155024
# 2       0.493546
# 3       1.215274
# 4       0.658915
#           ...
# 1995    1.656260
# 1996    0.383299
# 1997    0.217930
# 1998    0.769162
# 1999    0.714039
# Name: int_memory, Length: 2000, dtype: float64

# %%
from scipy import stats
 
z = np.abs(stats.zscore(df['ram']))
print(z)
# Out:
# 625     0.204514
# 1115    0.878581
# 1618    0.499591
# 1027    0.438202
# 736     1.677528
#           ...
# 327     0.739734
# 1682    0.798750
# 753     0.103081
# 309     0.432669
# 1354    0.172240
# Name: ram, Length: 2000, dtype: float64

# %%
df.nlargest(10, ['battery_power'])
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1354           1998     1          1.2         0   8       0          31
# 309            1997     1          1.8         1   1       0          40
# 1682           1996     1          2.8         1   0       1           7
# 753            1996     0          2.5         0   5       1          51
# 292            1995     1          1.9         0   6       0           9
# 327            1995     1          0.5         0   6       0          26
# 1240           1994     1          0.8         1   2       1           7
# 1540           1994     1          0.7         0   5       0           5
# 655            1994     0          1.5         1   2       1           7
# 637            1993     1          0.5         0  10       1          27
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1354    0.6        196        8  ...         50      1356  2311    17     9
# ...

# %%
def z_score(df,field):
    data =df[field].to_numpy()
    mean=np.mean(data)
    std=np.std(data)
    return df.query(f"({field} - {mean})/{std}>3")

# %%
field="dual_sim"
df=df.dropna(subset=[field])
df=df.sort_values(by=field)
documentation=z_score(df,field)
documentation
# Out:
# Empty DataFrame
# Columns: [battery_power, blue, clock_speed, dual_sim, fc, four_g, int_memory, m_dep, mobile_wt, n_cores, pc, px_height, px_width, ram, sc_h, sc_w, talk_time, three_g, touch_screen, wifi, price_range]
# Index: []
#
# [0 rows x 21 columns]

# %%
plt.scatter(df["battery_power"],df["ram"])

# %%
df["px_height"]
# Out:
# 1745     84
# 1330    439
# 1982    610
# 1354     50
# 1761    380
#        ...
# 555     416
# 723     613
# 683     729
# 578     163
# 940     815
# Name: px_height, Length: 2000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit_transform(df[['px_height']])
# Out:
# array([[-1.26469716],
#        [-0.46455264],
#        [-0.07913091],
#        ...,
#        [ 0.18908655],
#        [-1.08663683],
#        [ 0.38292437]])

# %%
print(f"Number of outliers:{len(df)}\nGreater outlier: {max(df['ram'])}")
# Out:
# Number of outliers:2000
# Greater outlier: 3998

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...
